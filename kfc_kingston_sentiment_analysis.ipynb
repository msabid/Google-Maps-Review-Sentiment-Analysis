# %% [markdown]
# <a href="https://colab.research.google.com/github/msabid/kfc-kingston-sentiment-analysis/blob/main/kfc_kingston_sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Library Calling

# %%
import urllib.parse
import requests
import pprint
import pandas as pd
from google.colab import userdata
from google.cloud import language_v1
from google.colab import drive

# %% [markdown]
# # Data Extraction

# %%
# Get Google Maps API key
googleMapsKey = userdata.get('google-maps-key')

# %%
# Function for finding the place
def geoCodePlace(query, location, radius):
    """Returns the places for the given query and location."""
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
        "keyword": query,
        "location": location,
        "radius": radius,
        "key": googleMapsKey
    }
    response = requests.get(url, params=urllib.parse.urlencode(params))
    return response.json()

# Function for getting place details
def getPlaceDetails(place_id):
    """Returns the place details for the given place id."""
    url = "https://maps.googleapis.com/maps/api/place/details/json"
    params = {
        "place_id": place_id,
        "fields": "place_id,name,rating,user_ratings_total,reviews,vicinity",
        "key": googleMapsKey,
    }
    response = requests.get(url, params=urllib.parse.urlencode(params))
    return response.json()


# Function to analyze sentiment
def analyze_sentiment(text):
    document = language_v1.types.Document(
        content=text, type_=language_v1.types.Document.Type.PLAIN_TEXT
    )
    sentiment = client.analyze_sentiment(
        request={"document": document}
    ).document_sentiment
    return sentiment.score, sentiment.magnitude

# %%
# Define the query and location
query = "KFC"
location = "44.2312,-76.4860"  # Latitude and longitude of Kingston, Ontario
radius = 10000  # Search radius in meters

# %%
# Get the geoCodedPlace
geoCodedPlace = geoCodePlace(query, location, radius)
print("\nThese are the KFC locations in Kingston, Ontario:")
pprint.pprint(geoCodedPlace)
# Out:
# These are the KFC locations in Kingston, Ontario:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 44.2505023, 'lng': -76.5306963},
#                            'viewport': {'northeast': {'lat': 44.25183257989273,
#                                                       'lng': -76.52932372010729},
#                                         'southwest': {'lat': 44.24913292010729,
#                                                       'lng': -76.53202337989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'KFC',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1920,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110432467253334971680">KFC</a>'],
#                           'photo_reference': 'AUGGfZn4KO1VGJcjT-_2VWxMNNqx9uatfYqlIzqG6Qh89QH6_ldnhNadN1B9VVQ_b6v7FqXf8cRcEswJDZOrkLPmngDydJ69r22ZMv5ihYhlPcrEA5sI_LW8CuXbYaICvtvJ977GPZ07HqMGz4yejJ6FEBdvQ0JvUdwnC0jxVFH6aYgZBfrW',
#                           'width': 1920}],
#               'place_id': 'ChIJ15h7AXes0kwRB6vBYdACEY0',
#               'plus_code': {'compound_code': '7F29+6Q Kingston, Ontario, '
#                                              'Canada',
#                             'global_code': '87P57F29+6Q'},
#               'price_level': 1,
#               'rating': 3,
#               'reference': 'ChIJ15h7AXes0kwRB6vBYdACEY0',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 379,
#               'vicinity': '1407 Princess St, Kingston'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 44.2563363,
#                                         'lng': -76.57217100000001},
#                            'viewport': {'northeast': {'lat': 44.25767662989272,
#                                                       'lng': -76.57133032010728},
#                                         'southwest': {'lat': 44.25497697010728,
#                                                       'lng': -76.57402997989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'KFC',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1920,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110519969249233294049">KFC</a>'],
#                           'photo_reference': 'AUGGfZlKgZzy7nRkAT-k204Gkp8ud8spzoD5PXOrVz5cF4dbeHyRuvAX3fHnHkVclrWnJltnmobz6BkvVeys5icVGUmZWG1ZJGSeWrSFQhEYJrb2On81B1lNwHZvIvZ8KONI6FBlV0PnfcOnqoOecc7nnFVWdahxgP_4RvesRy_lJLy9QOmO',
#                           'width': 1920}],
#               'place_id': 'ChIJT1mRDEus0kwRj6busiW3kUo',
#               'plus_code': {'compound_code': '7C4H+G4 Kingston, Ontario, '
#                                              'Canada',
#                             'global_code': '87P57C4H+G4'},
#               'price_level': 1,
#               'rating': 3,
#               'reference': 'ChIJT1mRDEus0kwRj6busiW3kUo',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 91,
#               'vicinity': '945 Gardiners Rd, Kingston'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 44.2377322, 'lng': -76.5691379},
#                            'viewport': {'northeast': {'lat': 44.23908962989272,
#                                                       'lng': -76.56789877010728},
#                                         'southwest': {'lat': 44.23638997010728,
#                                                       'lng': -76.57059842989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'KFC',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1920,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116792686027506557421">KFC</a>'],
#                           'photo_reference': 'AUGGfZlodlGs8emH5gpjRBNYsLPey0ggEqMfcnQElBAqdboCMLbrc1xKP_pHMb2TS-cIWj0kZSzaDraXsqb6tKqc6uI8O6ZHL49B9-VSl8o4aYyipd-gPZRtjd4Yo8dCNUHfawygFW28OP7p1YJac1_HFMQoom63pdkhN2SW686IlWnHoVqr',
#                           'width': 1920}],
#               'place_id': 'ChIJ6Z8PE4es0kwRSmh1CnDGRX0',
#               'plus_code': {'compound_code': '6CQJ+38 Kingston, Ontario, '
#                                              'Canada',
#                             'global_code': '87P56CQJ+38'},
#               'price_level': 1,
#               'rating': 2.7,
#               'reference': 'ChIJ6Z8PE4es0kwRSmh1CnDGRX0',
#               'scope': 'GOOGLE',
#               'types': ['meal_delivery',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 148,
#               'vicinity': '1668 Bath Rd, Kingston'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 44.2669598, 'lng': -76.5000012},
#                            'viewport': {'northeast': {'lat': 44.26819612989272,
#                                                       'lng': -76.49878032010727},
#                                         'southwest': {'lat': 44.26549647010727,
#                                                       'lng': -76.50147997989271}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'KFC',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1920,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101587861773748631688">KFC</a>'],
#                           'photo_reference': 'AUGGfZmRPnJL8gNMRC-r21aomLQM2YNGWH9JqQuiqP1mGzrpC3dgdfIrBX7RCTIo2ikB7LNU3yKHMvkJZ92F4wasTbQ_KJmXujhcMoDji2arGfB4lGN8oNFMBicwidLqtyvemnEO5TeonMK7eAVIlarjt1kWybf6IBsAT9kWdflT1NBbCOA2',
#                           'width': 1920}],
#               'place_id': 'ChIJW4n0HeSr0kwRO0pPiPa4xeM',
#               'plus_code': {'compound_code': '7F8X+QX Kingston, Ontario, '
#                                              'Canada',
#                             'global_code': '87P57F8X+QX'},
#               'price_level': 1,
#               'rating': 3.3,
#               'reference': 'ChIJW4n0HeSr0kwRO0pPiPa4xeM',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 558,
#               'vicinity': '29 Warne Crescent, Kingston'}],
#  'status': 'OK'}

# %%
# Extract place_ids
place_ids = [place['place_id'] for place in geoCodedPlace['results']]
print("\nThe place ids are:")
pprint.pprint(place_ids)
# Out:
# The place ids are:
# ['ChIJ15h7AXes0kwRB6vBYdACEY0',
#  'ChIJT1mRDEus0kwRj6busiW3kUo',
#  'ChIJ6Z8PE4es0kwRSmh1CnDGRX0',
#  'ChIJW4n0HeSr0kwRO0pPiPa4xeM']

# %%
# Initialize a list to store review data
review_data = []

# Get place details for each place_id
for place_id in place_ids:
    placeDetails = getPlaceDetails(place_id)
    print("\nThese are the place details:")
    pprint.pprint(placeDetails)

    if 'result' in placeDetails and 'reviews' in placeDetails['result']:
        reviews = placeDetails['result']['reviews']
        for i in range(min(3, len(reviews))):  # Ensure we only attempt to access up to 3 reviews
            review = reviews[i]
            publish_time = review.get('time', 0)
            if publish_time:
                publish_time = pd.to_datetime(publish_time, unit='s').isoformat() + 'Z'
            data = {
                'place_id': place_id,
                'publishTime': publish_time,
                'DisplayName': review.get('author_name', ''),
                'OriginalText': review.get('text', ''),
                'Rating': review.get('rating', '')
            }
            review_data.append(data)
            print(f"Appended review data: {data}")
    else:
        print(f"No reviews found for place_id {place_id}")
# Out:
# These are the place details:
# {'html_attributions': [],
#  'result': {'name': 'KFC',
#             'place_id': 'ChIJ15h7AXes0kwRB6vBYdACEY0',
#             'rating': 3,
#             'reviews': [{'author_name': 'Kate Gollogly',
#                          'author_url': 'https://www.google.com/maps/contrib/114555211384266547567/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocJ1Q-Z_IpMD4VROCfsvGkM4BCxcu7_3p8zMTwxqEIvXdWwGTA=s128-c0x00000000-cc-rp-mo-ba6',
#                          'rating': 4,
#                          'relative_time_description': 'a month ago',
#                          'text': 'Visited on a Tuesday around 5pm, restaurant '
#                                  'was not overly busy.  I ordered two popcorn '
#                                  'chicken meals. The popcorn chicken was '
#                                  'freshly made, as I had to wait about 4 '
#                                  'minutes.   Overall a good quick meal on the '
#                                  'go.  The only thing I would have liked, was '
#                                  'a few more napkins.',
#                          'time': 1713602886,
#                          'translated': False},
#                         {'author_name': 'Karim Merchant',
#                          'author_url': 'https://www.google.com/maps/contrib/116492299416841279903/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjUQieuqhJ1MOWLWUpjD-0X9Awe7bJbXyWEbip6W1qCb6zYMz01x=s128-c0x00000000-cc-rp-mo-ba4',
#                          'rating': 2,
#                          'relative_time_description': '7 months ago',
#                          'text': 'Chicken was stale didn’t seem fresh. Color '
#                                  'was dark probably oil was not changed or '
#                                  'this was re fryed. I also Ordered 3 sides '
#                                  'one coleslaw, fries and corn. I received 2 '
#                                  'coleslaw and 1 fries',
#                          'time': 1698545339,
#                          'translated': False},
#                         {'author_name': 'Moiz Master',
#                          'author_url': 'https://www.google.com/maps/contrib/101092097177363113144/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjX5YUcpO_QEwS62RMMP51HUFpA8auzq3x9nRdHOh9Tw_-E557XcLQ=s128-c0x00000000-cc-rp-mo-ba3',
#                          'rating': 1,
#                          'relative_time_description': '2 months ago',
#                          'text': 'The worst burger I have ever had in my life. '
#                                  'It felt like I was chewing stale recycled '
#                                  'cardboard put through oil from months ago. '
#                                  'The fries were soggier than a limp .... '
#                                  'Carrot 🍌. The saving grace was the Pepsi, '
#                                  "thank God it wasn't made here.\n"
#                                  '\n'
#                                  'If this is the accepted standard for KFC I '
#                                  "can't trust any other franchise ever again. "
#                                  'Goodbye KFC. Save what is left of your '
#                                  'reputation and shut this down.',
#                          'time': 1710542763,
#                          'translated': False},
#                         {'author_name': 'Brad Delaney',
#                          'author_url': 'https://www.google.com/maps/contrib/106139170847750738343/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjXNXo7J_aKk33CI1cGmsFAQsfi8gsTeIIr2sOA_WJ9G9b2A7-Yo=s128-c0x00000000-cc-rp-mo-ba3',
#                          'rating': 2,
#                          'relative_time_description': '7 months ago',
#                          'text': 'Went to this location and ordered a 14 piece '
#                                  'feast paid just about 50 dollars and all I '
#                                  'recieved in the chicken bucket was 9 legs '
#                                  'and 5 thighs no breast meat at all very '
#                                  'disappointing then I was going to call and '
#                                  'complain and realize that this location is '
#                                  'the only KFC without a listed phone number '
#                                  'and after reading all the bad reviews I '
#                                  'think KFC should not allow this type of '
#                                  'service and should look into this location '
#                                  'as you are not paying for what you get',
#                          'time': 1696098222,
#                          'translated': False},
#                         {'author_name': 'Sienna LC',
#                          'author_url': 'https://www.google.com/maps/contrib/105929841218181753382/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjVcDcq5iDkDh50dc9_53s3tClsCiznoRT5qBeSmpP34vU8grJzQ=s128-c0x00000000-cc-rp-mo',
#                          'rating': 5,
#                          'relative_time_description': '3 months ago',
#                          'text': 'On Family day, Monday Feb 19th around 6ish '
#                                  'we ordered on the KFC mobile app for Bath Rd '
#                                  'location. We showed up and they were closed, '
#                                  'yet 45$ gone from our accounts. Came to this '
#                                  'location around 6:30 and explained the '
#                                  'situation to the worker who was at the cash. '
#                                  'He called his manager and they were more '
#                                  'than willing to give us our order without '
#                                  'having to repay. It was really kind of them. '
#                                  'Then when we received our order, he let us '
#                                  'know he threw extra chicken in the bucket '
#                                  'for us because of the entire situation. We '
#                                  'really appreciated how nice they were '
#                                  'willing to help us! It was also only 2 guys '
#                                  'working and so busy around this time and yet '
#                                  'still took our order and went beyond! '
#                                  'Thankyou again!!',
#                          'time': 1708565698,
#                          'translated': False}],
#             'user_ratings_total': 379,
#             'vicinity': '1407 Princess Street, Kingston'},
#  'status': 'OK'}
# Appended review data: {'place_id': 'ChIJ15h7AXes0kwRB6vBYdACEY0', 'publishTime': '2024-04-20T08:48:06Z', 'DisplayName': 'Kate Gollogly', 'OriginalText': 'Visited on a Tuesday around 5pm, restaurant was not overly busy.  I ordered two popcorn chicken meals. The popcorn chicken was freshly made, as I had to wait about 4 minutes.   Overall a good quick meal on the go.  The only thing I would have liked, was a few more napkins.', 'Rating': 4}
# Appended review data: {'place_id': 'ChIJ15h7AXes0kwRB6vBYdACEY0', 'publishTime': '2023-10-29T02:08:59Z', 'DisplayName': 'Karim Merchant', 'OriginalText': 'Chicken was stale didn’t seem fresh. Color was dark probably oil was not changed or this was re fryed. I also Ordered 3 sides one coleslaw, fries and corn. I received 2 coleslaw and 1 fries', 'Rating': 2}
# Appended review data: {'place_id': 'ChIJ15h7AXes0kwRB6vBYdACEY0', 'publishTime': '2024-03-15T22:46:03Z', 'DisplayName': 'Moiz Master', 'OriginalText': "The worst burger I have ever had in my life. It felt like I was chewing stale recycled cardboard put through oil from months ago. The fries were soggier than a limp .... Carrot 🍌. The saving grace was the Pepsi, thank God it wasn't made here.\n\nIf this is the accepted standard for KFC I can't trust any other franchise ever again. Goodbye KFC. Save what is left of your reputation and shut this down.", 'Rating': 1}
#
# These are the place details:
# {'html_attributions': [],
#  'result': {'name': 'KFC',
#             'place_id': 'ChIJT1mRDEus0kwRj6busiW3kUo',
#             'rating': 3,
#             'reviews': [{'author_name': 'YaISaidIt',
#                          'author_url': 'https://www.google.com/maps/contrib/102762981374977036032/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocKabMFlPmALU4-cYU6bLi_VOk7_-hnw4tuBOCRKy9t27NFj0Q=s128-c0x00000000-cc-rp-mo-ba3',
#                          'rating': 2,
#                          'relative_time_description': '3 months ago',
#                          'text': 'KFC at the mall for fried chicken, fries, '
#                                  'gravy, coleslaw and tried churros. Remember '
#                                  'when KFC fried chicken used to have flavour? '
#                                  'Crisp? Coating that you could pull off and '
#                                  'enjoy by itself before eating the piece of '
#                                  'chicken? Well it doesn’t exist anymore. '
#                                  'Flat, thin, tasteless, soggy stuff now. It’s '
#                                  'sad. Fries were ok. Gravy was 1/2 full. '
#                                  'Medium coleslaw was in 2 small containers, '
#                                  'so that’s the same I guess- that is good but '
#                                  'not the bright green spicy stuff they used '
#                                  'to make. Meh. The service was great tho.',
#                          'time': 1706637855,
#                          'translated': False},
#                         {'author_name': 'Aivy Faye de Guzman-Bonabon',
#                          'author_url': 'https://www.google.com/maps/contrib/112231458270552347031/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjXZz5LyZKxF1LTq5fdhmUHrqnuQHHEpGz-M9fSHNl8nAOL3DETv=s128-c0x00000000-cc-rp-mo-ba2',
#                          'rating': 1,
#                          'relative_time_description': '6 months ago',
#                          'text': 'Terrible experience about survey '
#                                  'promotions.\n'
#                                  '\n'
#                                  'I recently had a disappointing experience at '
#                                  'the KFC Cataraqui Center. Despite my efforts '
#                                  'to participate in their survey promotion and '
#                                  'claim a free small popcorn chicken with any '
#                                  '(take note: ANY) purchase of a fountain '
#                                  'drink, the staff’s lack of awareness and '
#                                  'unimpressive behavior left me frustrated.\n'
#                                  '\n'
#                                  'Everytime I visited this branch and '
#                                  'presented my survey receipt for the promised '
#                                  'free small chicken popcorn, the staff seemed '
#                                  'completely unaware of the promotion with '
#                                  'their poker and blank face. Instead of a '
#                                  'smooth and quick process, I was consistently '
#                                  'kept waiting as the staff fumbled to '
#                                  'understand the promo details. This only '
#                                  'shows lack of awareness reflects poorly on '
#                                  'the management’s communication with their '
#                                  'staffs.\n'
#                                  '\n'
#                                  'To add, when I inquired about the cost of '
#                                  'their smallest fountain drink, I was told '
#                                  'that it was $1.05. However, when I attempted '
#                                  'to claim the free small popcorn with my '
#                                  'drink purchase, I am charged around $3. The '
#                                  'inconsistency between what the staff '
#                                  'communicated and the actual charges is I '
#                                  'think not fair. The receipt clearly states '
#                                  'that a free chicken popcorn is available '
#                                  'with any purchase of ANY fountain drink, but '
#                                  'the staff insisted on charging me more. It’s '
#                                  'just so disappointing. If the promotion is '
#                                  'contingent on a specific drink purchase '
#                                  'amount, this info should be clearly stated '
#                                  'on the receipt to avoid confusion and '
#                                  'frustration for customers. I hope that KFC '
#                                  'management address these issues promptly. I '
#                                  'rarely give Google reviews, but you know, '
#                                  'this left me thoroughly dissatisfied.',
#                          'time': 1700255058,
#                          'translated': False},
#                         {'author_name': 'Vodka Toxic',
#                          'author_url': 'https://www.google.com/maps/contrib/118404891810697597388/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocKY4kEd6XLaGOiuO8JNmwU6ep5GbkAkdmvOyZKwTQuLdKZeHA=s128-c0x00000000-cc-rp-mo',
#                          'rating': 1,
#                          'relative_time_description': '7 months ago',
#                          'text': 'I found the price very high for just 10 '
#                                  'chicken nuggets. The nuggets are very small, '
#                                  'and KFC does not cook to order, they just '
#                                  'grab them from a heated cabinet. Not very '
#                                  'hot, not very crispy. They just taste like '
#                                  'grease. I found a hair underneath all the '
#                                  'nuggets. The 10-piece nuggets came up on the '
#                                  'register and it said "no dip cup" '
#                                  'underneath. I wondered "Why am I not getting '
#                                  'a dip for buying 10 nuggets?". Well, the '
#                                  'cashier threw a "KFC Sauce" into the bag. I '
#                                  'had no idea what it was, she did not ask '
#                                  "what dip I'd like. It's a gross looking "
#                                  'puke-colored dijon honey mustard. Go to '
#                                  'Popeyes.',
#                          'time': 1698089950,
#                          'translated': False},
#                         {'author_name': 'Ashley Sparkman',
#                          'author_url': 'https://www.google.com/maps/contrib/111998014231736248552/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjX76EA8RtyoSjcXIP97Fq_xLoWFVDQPMnw24TBnVzhZDJLllvwb=s128-c0x00000000-cc-rp-mo-ba3',
#                          'rating': 2,
#                          'relative_time_description': '7 months ago',
#                          'text': 'I typically love KFC/Taco Bell. This '
#                                  'particular location is awful. It is badly '
#                                  'understaffed so everyone waits forever for '
#                                  'one person to take your order and then go '
#                                  'back and make it, I’ve never seen that '
#                                  'person wash their hands between handling the '
#                                  'cash and handling the food. If you’re lucky '
#                                  'there are two people. There is so much '
#                                  'grease in the tacos, it drips out while you '
#                                  'are trying to eat them. The fries are '
#                                  'usually old and hard, which is weird because '
#                                  'you’re always waiting so long for food. It’s '
#                                  'too expensive for what you get. Oh, and the '
#                                  'carbonation in the soda machine is turned up '
#                                  'way too high.',
#                          'time': 1696106128,
#                          'translated': False},
#                         {'author_name': 'Anthony Ansari',
#                          'author_url': 'https://www.google.com/maps/contrib/111409698388324920034/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocKxslE8q0sOHz4FxOzt13x4IG2WFqsz-ySaeBet8SO8BEcFOQ=s128-c0x00000000-cc-rp-mo-ba3',
#                          'rating': 1,
#                          'relative_time_description': '6 years ago',
#                          'text': 'I worked for kfc and I loved working there '
#                                  'but I left for heath issues and now I wanted '
#                                  'some for food and I went and bought they '
#                                  'gave me some small size chicken and one tiny '
#                                  'size chicken peace. Very disappointed they '
#                                  'said its new cuts your suppose to get more '
#                                  'meat big lie one peace was smaller then a '
#                                  'chicken nugget at McDonalds and gave 6 '
#                                  'peaces of pop corn chicken',
#                          'time': 1506201590,
#                          'translated': False}],
#             'user_ratings_total': 91,
#             'vicinity': '945 Gardiners Road, Kingston'},
#  'status': 'OK'}
# Appended review data: {'place_id': 'ChIJT1mRDEus0kwRj6busiW3kUo', 'publishTime': '2024-01-30T18:04:15Z', 'DisplayName': 'YaISaidIt', 'OriginalText': 'KFC at the mall for fried chicken, fries, gravy, coleslaw and tried churros. Remember when KFC fried chicken used to have flavour? Crisp? Coating that you could pull off and enjoy by itself before eating the piece of chicken? Well it doesn’t exist anymore. Flat, thin, tasteless, soggy stuff now. It’s sad. Fries were ok. Gravy was 1/2 full. Medium coleslaw was in 2 small containers, so that’s the same I guess- that is good but not the bright green spicy stuff they used to make. Meh. The service was great tho.', 'Rating': 2}
# Appended review data: {'place_id': 'ChIJT1mRDEus0kwRj6busiW3kUo', 'publishTime': '2023-11-17T21:04:18Z', 'DisplayName': 'Aivy Faye de Guzman-Bonabon', 'OriginalText': 'Terrible experience about survey promotions.\n\nI recently had a disappointing experience at the KFC Cataraqui Center. Despite my efforts to participate in their survey promotion and claim a free small popcorn chicken with any (take note: ANY) purchase of a fountain drink, the staff’s lack of awareness and unimpressive behavior left me frustrated.\n\nEverytime I visited this branch and presented my survey receipt for the promised free small chicken popcorn, the staff seemed completely unaware of the promotion with their poker and blank face. Instead of a smooth and quick process, I was consistently kept waiting as the staff fumbled to understand the promo details. This only shows lack of awareness reflects poorly on the management’s communication with their staffs.\n\nTo add, when I inquired about the cost of their smallest fountain drink, I was told that it was $1.05. However, when I attempted to claim the free small popcorn with my drink purchase, I am charged around $3. The inconsistency between what the staff communicated and the actual charges is I think not fair. The receipt clearly states that a free chicken popcorn is available with any purchase of ANY fountain drink, but the staff insisted on charging me more. It’s just so disappointing. If the promotion is contingent on a specific drink purchase amount, this info should be clearly stated on the receipt to avoid confusion and frustration for customers. I hope that KFC management address these issues promptly. I rarely give Google reviews, but you know, this left me thoroughly dissatisfied.', 'Rating': 1}
# Appended review data: {'place_id': 'ChIJT1mRDEus0kwRj6busiW3kUo', 'publishTime': '2023-10-23T19:39:10Z', 'DisplayName': 'Vodka Toxic', 'OriginalText': 'I found the price very high for just 10 chicken nuggets. The nuggets are very small, and KFC does not cook to order, they just grab them from a heated cabinet. Not very hot, not very crispy. They just taste like grease. I found a hair underneath all the nuggets. The 10-piece nuggets came up on the register and it said "no dip cup" underneath. I wondered "Why am I not getting a dip for buying 10 nuggets?". Well, the cashier threw a "KFC Sauce" into the bag. I had no idea what it was, she did not ask what dip I\'d like. It\'s a gross looking puke-colored dijon honey mustard. Go to Popeyes.', 'Rating': 1}
#
# These are the place details:
# {'html_attributions': [],
#  'result': {'name': 'KFC',
#             'place_id': 'ChIJ6Z8PE4es0kwRSmh1CnDGRX0',
#             'rating': 2.7,
#             'reviews': [{'author_name': 'Kat J',
#                          'author_url': 'https://www.google.com/maps/contrib/106515486437205973971/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjUd0InMNqBG4RsxEcZXXUajRIvazWs1IYwO4XobjJemxI49q5AecA=s128-c0x00000000-cc-rp-mo-ba5',
#                          'rating': 3,
#                          'relative_time_description': '5 months ago',
#                          'text': 'This KFC is combined with a Taco Bell but '
#                                  'you can’t order at the same counter for '
#                                  'both. The service here is incredibly slow. '
#                                  'The chicken is not like the typical chicken, '
#                                  'it wasn’t bad, but not what was expected. '
#                                  'The restaurant itself was very clean, the '
#                                  'bathrooms and tables were clean. There are '
#                                  'cute signs on the walls too which adds a bit '
#                                  'of modernness to the store',
#                          'time': 1701920076,
#                          'translated': False},
#                         {'author_name': 'First Last',
#                          'author_url': 'https://www.google.com/maps/contrib/111430314097071359838/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocJr3Pg9aANWyaj-BVlM3qqigs_NOdKVGYfBXsfRnftt_2fP1g=s128-c0x00000000-cc-rp-mo',
#                          'rating': 1,
#                          'relative_time_description': '2 years ago',
#                          'text': 'Ordered a bucket of chicken with sides and '
#                                  'popcorn chicken for my kids, they screwed up '
#                                  'the order ended up giving 3 boxs of fries '
#                                  'instead of the popcorn chicken which is not '
#                                  'a super big deal if the fries werent soggy, '
#                                  'the gravy is basically grease flavoured '
#                                  'water. The chicken itself was very '
#                                  'overcooked covered in grease and pretty much '
#                                  'inedible. I would call and complain but most '
#                                  "they're going to do is offer me a deal for "
#                                  'the next time we go which is never because '
#                                  "the food is over priced trash and i won't be "
#                                  'going back. Hope this helps!',
#                          'time': 1646865176,
#                          'translated': False},
#                         {'author_name': 'Psycho Boo',
#                          'author_url': 'https://www.google.com/maps/contrib/106808698122401015366/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjUs___dr38SObiBWti8hl-mlz3ZqvWx2DA1PlJzzUc-KhPAJjQ=s128-c0x00000000-cc-rp-mo',
#                          'rating': 1,
#                          'relative_time_description': '4 months ago',
#                          'text': 'I miss when KFC used to be good and it '
#                                  "didn't taste like the chicken has been "
#                                  "sitting out all day. It's not crispy "
#                                  'anymore, the skin is soggy and gross now. '
#                                  'What happened KFC?',
#                          'time': 1703984818,
#                          'translated': False},
#                         {'author_name': 'Jordan Gall',
#                          'author_url': 'https://www.google.com/maps/contrib/113600877824957332918/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWkAvan-cFL_rSwqrBXAHPjtcFkucQu1UybCSIgRVqOJ5Bo9bA=s128-c0x00000000-cc-rp-mo',
#                          'rating': 1,
#                          'relative_time_description': '2 months ago',
#                          'text': 'Why do you put rotten lettuce on my burger',
#                          'time': 1710690546,
#                          'translated': False},
#                         {'author_name': 'Sandy Peebsen',
#                          'author_url': 'https://www.google.com/maps/contrib/100376477215963001792/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocJ249GEr3LIWJIKzB-ZVXK0cLo3m_mavNoNIEHtSYsP_VGEsA=s128-c0x00000000-cc-rp-mo',
#                          'rating': 2,
#                          'relative_time_description': '9 months ago',
#                          'text': 'Not good. My combo was supposed to include 4 '
#                                  'pieces of dark meat chicken. There was none. '
#                                  'They gave me 2 wings and then cut one breast '
#                                  'into pieces and counted each as a piece. The '
#                                  "fries were mediocre at best and I've had "
#                                  'better chicken from a tv dinner. The chicken '
#                                  'tenders were decent, but no dipping sauce '
#                                  'was included. The popcorn chicken was very '
#                                  "bland. Even the sides couldn't save the day. "
#                                  'Never again. Bye-bye KFC.',
#                          'time': 1693261798,
#                          'translated': False}],
#             'user_ratings_total': 148,
#             'vicinity': '1668 Bath Road, Kingston'},
#  'status': 'OK'}
# Appended review data: {'place_id': 'ChIJ6Z8PE4es0kwRSmh1CnDGRX0', 'publishTime': '2023-12-07T03:34:36Z', 'DisplayName': 'Kat J', 'OriginalText': 'This KFC is combined with a Taco Bell but you can’t order at the same counter for both. The service here is incredibly slow. The chicken is not like the typical chicken, it wasn’t bad, but not what was expected. The restaurant itself was very clean, the bathrooms and tables were clean. There are cute signs on the walls too which adds a bit of modernness to the store', 'Rating': 3}
# Appended review data: {'place_id': 'ChIJ6Z8PE4es0kwRSmh1CnDGRX0', 'publishTime': '2022-03-09T22:32:56Z', 'DisplayName': 'First Last', 'OriginalText': "Ordered a bucket of chicken with sides and popcorn chicken for my kids, they screwed up the order ended up giving 3 boxs of fries instead of the popcorn chicken which is not a super big deal if the fries werent soggy, the gravy is basically grease flavoured water. The chicken itself was very overcooked covered in grease and pretty much inedible. I would call and complain but most they're going to do is offer me a deal for the next time we go which is never because the food is over priced trash and i won't be going back. Hope this helps!", 'Rating': 1}
# Appended review data: {'place_id': 'ChIJ6Z8PE4es0kwRSmh1CnDGRX0', 'publishTime': '2023-12-31T01:06:58Z', 'DisplayName': 'Psycho Boo', 'OriginalText': "I miss when KFC used to be good and it didn't taste like the chicken has been sitting out all day. It's not crispy anymore, the skin is soggy and gross now. What happened KFC?", 'Rating': 1}
#
# These are the place details:
# {'html_attributions': [],
#  'result': {'name': 'KFC',
#             'place_id': 'ChIJW4n0HeSr0kwRO0pPiPa4xeM',
#             'rating': 3.3,
#             'reviews': [{'author_name': 'Bibin Chacko',
#                          'author_url': 'https://www.google.com/maps/contrib/115158807723508427698/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjU7jNCzTX9cqHLKwEL5JV1l1N-QAF-q09i00mphr2NTVro4mox6-w=s128-c0x00000000-cc-rp-mo-ba5',
#                          'rating': 5,
#                          'relative_time_description': 'in the last week',
#                          'text': 'The chicken was well made , good to try. But '
#                                  'I am just concerned that the salt was way '
#                                  'more. Please try to reduce salt so that it '
#                                  'can be little better . Good service and '
#                                  'clean store , even though it’s a busy store.',
#                          'time': 1716238471,
#                          'translated': False},
#                         {'author_name': 'Dan Lake',
#                          'author_url': 'https://www.google.com/maps/contrib/117139248403275877414/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocIG-5msbh0kqx5fvrZquKiDgLKUsO6FtUt18NrW2B4sIuKKuA=s128-c0x00000000-cc-rp-mo',
#                          'rating': 1,
#                          'relative_time_description': 'in the last week',
#                          'text': 'Service when ordering  was good, but every '
#                                  'table in dining area was filthy there were '
#                                  'no customers. Had to tell them all the '
#                                  'tables were dirty so someone would come '
#                                  'clean them.',
#                          'time': 1716145203,
#                          'translated': False},
#                         {'author_name': 'R Hon',
#                          'author_url': 'https://www.google.com/maps/contrib/112664530969744153211/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjU2qOR_bOciWuoNgkidSt-WLR8iAuEDBy2BWO_WMHblePJ6Wfva=s128-c0x00000000-cc-rp-mo-ba4',
#                          'rating': 2,
#                          'relative_time_description': '2 weeks ago',
#                          'text': 'The men washroom is never been washed and '
#                                  'the garbage bin was full at the restaurant. '
#                                  'The KFC chicken quality is ok but just a bit '
#                                  'too much grease on the skin. The people '
#                                  'working in the kitchen can move a bit faster',
#                          'time': 1715206780,
#                          'translated': False},
#                         {'author_name': 'Julia Potter',
#                          'author_url': 'https://www.google.com/maps/contrib/114303745889123302075/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjXn6OJ76oIx1MjZw1V2OWsAjafL6sU6GtmKQkr-Xw712mqlcItM=s128-c0x00000000-cc-rp-mo',
#                          'rating': 1,
#                          'relative_time_description': 'in the last week',
#                          'text': 'The experience was very lack luster. '
#                                  'Communication was horrible. The chicken was '
#                                  "fully cooked. This was a mother's day treat "
#                                  'for my mom and she was disappointed by the '
#                                  'chicken.',
#                          'time': 1716150186,
#                          'translated': False},
#                         {'author_name': 'Brian McNaught',
#                          'author_url': 'https://www.google.com/maps/contrib/107386231082588301241/reviews',
#                          'language': 'en',
#                          'original_language': 'en',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWQPcSaFrGeuCIRg4JqwssI-amdw0kBpZky-r5FOOwSC_bpIzY=s128-c0x00000000-cc-rp-mo',
#                          'rating': 1,
#                          'relative_time_description': '5 months ago',
#                          'text': 'On December 5, I ordered an 18 pc bucket '
#                                  'meal for a lunch for 7 of my employees. It '
#                                  'cost me $80 and boy was I ever '
#                                  'disappointed!! The chicken was not fresh. '
#                                  'Probably leftover from the previous day so '
#                                  'it was very dry. Everything else was pretty '
#                                  'good but come on, chicken is what you do!! '
#                                  'Now you not only pi$$ed me off but all my '
#                                  'staff were all disappointed as well. I will '
#                                  'never order from KFC and waist my money. '
#                                  'Pizza party sounds better!!',
#                          'time': 1702008428,
#                          'translated': False}],
#             'user_ratings_total': 558,
#             'vicinity': '29 Warne Crescent, Kingston'},
#  'status': 'OK'}
# Appended review data: {'place_id': 'ChIJW4n0HeSr0kwRO0pPiPa4xeM', 'publishTime': '2024-05-20T20:54:31Z', 'DisplayName': 'Bibin Chacko', 'OriginalText': 'The chicken was well made , good to try. But I am just concerned that the salt was way more. Please try to reduce salt so that it can be little better . Good service and clean store , even though it’s a busy store.', 'Rating': 5}
# Appended review data: {'place_id': 'ChIJW4n0HeSr0kwRO0pPiPa4xeM', 'publishTime': '2024-05-19T19:00:03Z', 'DisplayName': 'Dan Lake', 'OriginalText': 'Service when ordering  was good, but every table in dining area was filthy there were no customers. Had to tell them all the tables were dirty so someone would come clean them.', 'Rating': 1}
# Appended review data: {'place_id': 'ChIJW4n0HeSr0kwRO0pPiPa4xeM', 'publishTime': '2024-05-08T22:19:40Z', 'DisplayName': 'R Hon', 'OriginalText': 'The men washroom is never been washed and the garbage bin was full at the restaurant. The KFC chicken quality is ok but just a bit too much grease on the skin. The people working in the kitchen can move a bit faster', 'Rating': 2}

# %%
# Create a DataFrame from the review data
df = pd.DataFrame(review_data)
df
# Out:
#                        place_id           publishTime  \
# 0   ChIJ15h7AXes0kwRB6vBYdACEY0  2024-04-20T08:48:06Z
# 1   ChIJ15h7AXes0kwRB6vBYdACEY0  2023-10-29T02:08:59Z
# 2   ChIJ15h7AXes0kwRB6vBYdACEY0  2024-03-15T22:46:03Z
# 3   ChIJT1mRDEus0kwRj6busiW3kUo  2024-01-30T18:04:15Z
# 4   ChIJT1mRDEus0kwRj6busiW3kUo  2023-11-17T21:04:18Z
# 5   ChIJT1mRDEus0kwRj6busiW3kUo  2023-10-23T19:39:10Z
# 6   ChIJ6Z8PE4es0kwRSmh1CnDGRX0  2023-12-07T03:34:36Z
# 7   ChIJ6Z8PE4es0kwRSmh1CnDGRX0  2022-03-09T22:32:56Z
# 8   ChIJ6Z8PE4es0kwRSmh1CnDGRX0  2023-12-31T01:06:58Z
# 9   ChIJW4n0HeSr0kwRO0pPiPa4xeM  2024-05-20T20:54:31Z
# 10  ChIJW4n0HeSr0kwRO0pPiPa4xeM  2024-05-19T19:00:03Z
# 11  ChIJW4n0HeSr0kwRO0pPiPa4xeM  2024-05-08T22:19:40Z
#
#                     DisplayName  \
# 0                 Kate Gollogly
# 1                Karim Merchant
# 2                   Moiz Master
# 3                     YaISaidIt
# 4   Aivy Faye de Guzman-Bonabon
# 5                   Vodka Toxic
# 6                         Kat J
# 7                    First Last
# 8                    Psycho Boo
# 9                  Bibin Chacko
# 10                     Dan Lake
# 11                        R Hon
#
#                                          OriginalText  Rating
# 0   Visited on a Tuesday around 5pm, restaurant wa...       4
# 1   Chicken was stale didn’t seem fresh. Color was...       2
# 2   The worst burger I have ever had in my life. I...       1
# 3   KFC at the mall for fried chicken, fries, grav...       2
# 4   Terrible experience about survey promotions.\n...       1
# 5   I found the price very high for just 10 chicke...       1
# 6   This KFC is combined with a Taco Bell but you ...       3
# 7   Ordered a bucket of chicken with sides and pop...       1
# 8   I miss when KFC used to be good and it didn't ...       1
# 9   The chicken was well made , good to try. But I...       5
# 10  Service when ordering  was good, but every tab...       1
# 11  The men washroom is never been washed and the ...       2

# %%
# Convert 'publishTime' to datetime format
df['publishTime'] = pd.to_datetime(df['publishTime'])
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   place_id      12 non-null     object
#  1   publishTime   12 non-null     datetime64[ns, UTC]
#  2   DisplayName   12 non-null     object
#  3   OriginalText  12 non-null     object
#  4   Rating        12 non-null     int64
# dtypes: datetime64[ns, UTC](1), int64(1), object(3)
# memory usage: 608.0+ bytes

# %%
# Initialize a list to store place details
place_details_data = []

# Get place details for each place_id and store required fields
for place_id in place_ids:
    placeDetails = getPlaceDetails(place_id)
    if 'result' in placeDetails:
        result = placeDetails['result']
        data = {
            'place_id': result.get('place_id', ''),
            'vicinity': result.get('vicinity', ''),
            'user_ratings_total': result.get('user_ratings_total', 0)
        }
        place_details_data.append(data)
        print(f"Appended place details: {data}")
    else:
        print(f"No details found for place_id {place_id}")
# Out:
# Appended place details: {'place_id': 'ChIJ15h7AXes0kwRB6vBYdACEY0', 'vicinity': '1407 Princess Street, Kingston', 'user_ratings_total': 379}
# Appended place details: {'place_id': 'ChIJT1mRDEus0kwRj6busiW3kUo', 'vicinity': '945 Gardiners Road, Kingston', 'user_ratings_total': 91}
# Appended place details: {'place_id': 'ChIJ6Z8PE4es0kwRSmh1CnDGRX0', 'vicinity': '1668 Bath Road, Kingston', 'user_ratings_total': 148}
# Appended place details: {'place_id': 'ChIJW4n0HeSr0kwRO0pPiPa4xeM', 'vicinity': '29 Warne Crescent, Kingston', 'user_ratings_total': 558}

# %%
df2 = pd.DataFrame(place_details_data)
df2
# Out:
#                       place_id                        vicinity  \
# 0  ChIJ15h7AXes0kwRB6vBYdACEY0  1407 Princess Street, Kingston
# 1  ChIJT1mRDEus0kwRj6busiW3kUo    945 Gardiners Road, Kingston
# 2  ChIJ6Z8PE4es0kwRSmh1CnDGRX0        1668 Bath Road, Kingston
# 3  ChIJW4n0HeSr0kwRO0pPiPa4xeM     29 Warne Crescent, Kingston
#
#    user_ratings_total
# 0                 379
# 1                  91
# 2                 148
# 3                 558

# %% [markdown]
# # Sentiment Analysis

# %%
# Initialize Google Cloud SDK
# !gcloud init
# Out:
# Welcome! This command will take you through the configuration of gcloud.
#
# Settings from your current configuration [default] are:
# component_manager:
#   disable_update_check: 'True'
# compute:
#   gce_metadata_read_timeout_sec: '0'
#
# Pick configuration to use:
#  [1] Re-initialize this configuration [default] with new settings
#  [2] Create a new configuration
# Please enter your numeric choice:  1
#
# Your current configuration has been set to: [default]
#
# You can skip diagnostics next time by using the following flag:
#   gcloud init --skip-diagnostics
#
# Network diagnostic detects and fixes local network connection issues.
# Reachability Check passed.
# Network diagnostic passed (1/1 checks passed).
#
# You must log in to continue. Would you like to log in (Y/n)?  Y
#
# Go to the following link in your browser, and complete the sign-in prompts:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fsdk.cloud.google.com%2Fauthcode.html&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=zGq9gi0hGEXi8swGgekVr4z9kxmzw2&prompt=consent&token_usage=remote&access_type=offline&code_challenge=4gDTrWUnw8-khieOiO5Sms4brYCHl1eou-R2pIHik94&code_challenge_method=S256
#
# Once finished, enter the verification code provided in your browser: 4/0AdLIrYeZQQOB0qQ-Gev424vuZbbSax07oyyd4-aD64FJ9X_1dbLOFbrCnWvTq6qF4RQjEg
# You are logged in as: [mushfiq.abid.5@gmail.com].
#
# Pick cloud project to use:
#  [1] admn5015-s24-ic-msabid
#  [2] lucid-sonar-424221-i7
#  [3] Enter a project ID
#  [4] Create a new project
# Please enter numeric choice or text value (must exactly match list item):  1
#
# Your current project has been set to: [admn5015-s24-ic-msabid].
#
# Not setting default zone/region (this feature makes it easier to use
# [gcloud compute] by setting an appropriate default value for the
# --zone and --region flag).
# See https://cloud.google.com/compute/docs/gcloud-compute section on how to set
# default compute region and zone manually. If you would like [gcloud init] to be
# able to do this for you the next time you run it, make sure the
# Compute Engine API is enabled for your project on the
# https://console.developers.google.com/apis page.
#
# Your Google Cloud SDK is configured and ready to use!
#
# * Commands that require authentication will use mushfiq.abid.5@gmail.com by default
# * Commands will reference project `admn5015-s24-ic-msabid` by default
# Run `gcloud help config` to learn how to change individual settings
#
# This gcloud configuration is called [default]. You can create additional configurations if you work with multiple accounts and/or projects.
# Run `gcloud topic configurations` to learn more.
#
# Some things to try next:
#
# * Run `gcloud --help` to see the Cloud Platform services you can interact with. And run `gcloud help COMMAND` to get help on any gcloud command.
# * Run `gcloud topic --help` to learn about advanced features of the SDK like arg files and output formatting
# * Run `gcloud cheat-sheet` to see a roster of go-to `gcloud` commands.

# %%
# Enable Google Cloud Natural Language API
# !gcloud services enable language.googleapis.com

# %%
# Authenticate to use Google Cloud services
# !gcloud auth application-default login
# Out:
# Go to the following link in your browser, and complete the sign-in prompts:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=764086051850-6qr4p6gpi6hn506pt8ejuq83di341hur.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fsdk.cloud.google.com%2Fapplicationdefaultauthcode.html&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login&state=orywK9QnAkJZa1rDg26V1DxuRDLPNZ&prompt=consent&token_usage=remote&access_type=offline&code_challenge=VvL1IOYIdFshylqrIuZbvfXQRD_QL4PerIdGHV1wQMQ&code_challenge_method=S256
#
# Once finished, enter the verification code provided in your browser: 4/0AdLIrYch0y3q5v85LU_51Xx9Y1zva0uwVRChnHfCK_Hg9uHs9xp9nCmasFcmShWq0Azhtg
#
# Credentials saved to file: [/content/.config/application_default_credentials.json]
#
# These credentials will be used by any library that requests Application Default Credentials (ADC).
#
# Quota project "admn5015-s24-ic-msabid" was added to ADC which can be used by Google client libraries for billing and quota. Note that some services may still bill the project owning the resource.

# %%
# Instantiates a client
client = language_v1.LanguageServiceClient()

# %%
# Apply sentiment analysis to each review
df['Sentiment_Score'] = df['OriginalText'].apply(lambda text: analyze_sentiment(text)[0])
df['Sentiment_Magnitude'] = df['OriginalText'].apply(lambda text: analyze_sentiment(text)[1])

# %%
df.head()
# Out:
#                       place_id               publishTime  \
# 0  ChIJ15h7AXes0kwRB6vBYdACEY0 2024-04-20 08:48:06+00:00
# 1  ChIJ15h7AXes0kwRB6vBYdACEY0 2023-10-29 02:08:59+00:00
# 2  ChIJ15h7AXes0kwRB6vBYdACEY0 2024-03-15 22:46:03+00:00
# 3  ChIJT1mRDEus0kwRj6busiW3kUo 2024-01-30 18:04:15+00:00
# 4  ChIJT1mRDEus0kwRj6busiW3kUo 2023-11-17 21:04:18+00:00
#
#                    DisplayName  \
# 0                Kate Gollogly
# 1               Karim Merchant
# 2                  Moiz Master
# 3                    YaISaidIt
# 4  Aivy Faye de Guzman-Bonabon
#
#                                         OriginalText  Rating  Sentiment_Score  \
# 0  Visited on a Tuesday around 5pm, restaurant wa...       4              0.3
# 1  Chicken was stale didn’t seem fresh. Color was...       2             -0.3
# 2  The worst burger I have ever had in my life. I...       1             -0.3
# 3  KFC at the mall for fried chicken, fries, grav...       2             -0.3
# 4  Terrible experience about survey promotions.\n...       1             -0.7
#
#    Sentiment_Magnitude
# 0                  1.9
# 1                  2.3
# 2                  4.6
# 3                  4.7
# 4                 10.7

# %% [markdown]
# # Exporting Data as CSV

# %%
# Mount Google Drive to save the data
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Export df and df2 as separate CSV files
df.to_csv('/content/drive/My Drive/ML&AI/store_data_reviews.csv', index=False)
df2.to_csv('/content/drive/My Drive/ML&AI/store_data_place_details.csv', index=False)
